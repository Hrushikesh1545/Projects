# %% [markdown]
# House Price Pridction

# %%
"Load Libraries"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar as cnd

# %%
"Load Data"

train_data_path = r"D:\sonu\project\house_price_pridction\Data\train.csv"
test_data_path = r"D:\sonu\project\house_price_pridction\Data\test.csv"

df_train = pd.read_csv(train_data_path)
df_test = pd.read_csv(test_data_path)

print("Shape of df_train:", df_train.shape)
print("Shape of df_test:", df_test.shape)
# Out:
# Shape of df_train: (1460, 81)
# Shape of df_test: (1459, 80)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_ov_data = pd.concat([df_train, df_test])

print("Shape of Intigreted Data/DF", df_ov_data.shape)
# Out:
# Shape of Intigreted Data/DF (2919, 81)

# %%
df_ov_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_ov_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_ov_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [raw]
# """ features having missing data """
# Alley
# MasVnrType
# FireplaceQu
# PoolQC
# Fence
# MiscFeature

# %%
int_feature = df_ov_data.select_dtypes(include="int64").columns
print("Total number of intiger features = ", int_feature.shape[0])
print("Intiger feature names = ", int_feature)
# Out:
# Total number of intiger features =  26
# Intiger feature names =  Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
float_feature = df_ov_data.select_dtypes(include="float64").columns
print("Total number of floating features = ", float_feature.shape[0])
print("floting feature names = ", float_feature)
# Out:
# Total number of floating features =  12
# floting feature names =  Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
cat_feature = df_ov_data.select_dtypes(include="object").columns
print("Total number of categorical features = ", cat_feature.shape[0])
print("categorical feature names = ", cat_feature)
# Out:
# Total number of categorical features =  43
# categorical feature names =  Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df_ov_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
df_ov_data.describe().shape
# Out:
# (8, 38)

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df_ov_data.isnull())
plt.savefig("D:\sonu\project\house_price_pridction\EDA_img\heatmap_df_of_null_values.png")

# %%
null_count = df_ov_data.isnull().sum()
null_count
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType       1766
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
df_ov_data = df_ov_data.set_index("Id")

# %%
null_percent = df_ov_data.isnull().sum()/df_ov_data.shape[0]*100
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
# Alley            93.216855
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.068517
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.034258
# Exterior2nd       0.034258
# MasVnrType       60.500171
# MasVnrArea        0.787941
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.774923
# BsmtCond          2.809181
# BsmtExposure      2.809181
# BsmtFinType1      2.706406
# BsmtFinSF1        0.034258
# ...

# %%
""" As per Domain Knowledge we will not drop this features, insted we will replace a constant value 'NA' with the null value """
miss_value_50_perc = null_percent[null_percent > 50]
miss_value_50_perc
# Out:
# Alley          93.216855
# MasVnrType     60.500171
# PoolQC         99.657417
# Fence          80.438506
# MiscFeature    96.402878
# dtype: float64

# %%
""" As per Domain Knowledge we will not drop this features, insted we will replace a constant value 'NA' with the null value """
miss_value_20_50_perc = null_percent[(null_percent > 20)&(null_percent < 51)]
miss_value_20_50_perc
# Out:
# FireplaceQu    48.646797
# SalePrice      49.982871
# dtype: float64

# %%
""" As per Domain Knowledge we will not drop this features, insted we will replace a constant value 'NA' with the null value """
miss_value_5_20_perc = null_percent[(null_percent > 5)&(null_percent < 21)]
miss_value_5_20_perc
# Out:
# LotFrontage     16.649538
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64

# %%
missing_value_features = null_percent[null_percent > 0]
print("Total missing values features = ", missing_value_features.shape[0])
missing_value_features
# Out:
# Total missing values features =  35
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# ...

# %%
int_NA_feature= missing_value_features[missing_value_features.keys().isin(int_feature)]
print("Total number of intiger missing features = ", int_NA_feature.shape[0])
int_NA_feature
# Out:
# Total number of intiger missing features =  0
# Series([], dtype: float64)

# %%
float_NA_feature= missing_value_features[missing_value_features.keys().isin(float_feature)]
print("Total number of floating missing features = ", float_NA_feature.shape[0])
float_NA_feature
# Out:
# Total number of floating missing features =  12
# LotFrontage     16.649538
# MasVnrArea       0.787941
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# GarageYrBlt      5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# SalePrice       49.982871
# dtype: float64

# %%
cat_NA_feature= missing_value_features[missing_value_features.keys().isin(cat_feature)]
print("Total number of categorical missing features = ", cat_NA_feature.shape[0])
cat_NA_feature
# Out:
# Total number of categorical missing features =  23
# MSZoning         0.137033
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
# Electrical       0.034258
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# dtype: float64

# %%
df_cleaned = df_ov_data.copy()
df_cleaned.shape
# Out:
# (2919, 80)

# %%
df_ov_data["MSZoning"].value_counts()
# Out:
# MSZoning
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: count, dtype: int64

# %%
sns.countplot(x=df_ov_data.get("MSZoning"))
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
mszoning_mode = df_ov_data["MSZoning"].mode()[0]
mszoning_mode
# Out:
# 'RL'

# %%
df_cleaned["MSZoning"].replace(np.nan, mszoning_mode, inplace=True)
df_cleaned["MSZoning"].isnull().sum()
# Out:
# 0

# %%
alley_const = "NA"
df_cleaned["Alley"].replace(np.nan, alley_const, inplace=True)
df_cleaned["Alley"].isnull().sum()
# Out:
# 0

# %%
lotfrontage_mwdian = df_ov_data["LotFrontage"].median()
lotfrontage_mwdian
# Out:
# 68.0

# %%
df_cleaned["LotFrontage"].replace(np.nan, lotfrontage_mwdian, inplace=True)
df_cleaned["LotFrontage"].isnull().sum()
# Out:
# 0

# %%
utilities_mode = df_ov_data["Utilities"].mode()[0]
utilities_mode
# Out:
# 'AllPub'

# %%
df_cleaned["Utilities"].replace(np.nan, utilities_mode, inplace=True)
df_cleaned["Utilities"].isnull().sum()
# Out:
# 0

# %%
exterior1st_mode = df_ov_data["Exterior1st"].mode()[0]
exterior1st_mode
# Out:
# 'VinylSd'

# %%
df_cleaned["Exterior1st"].replace(np.nan, exterior1st_mode, inplace=True)
df_cleaned["Exterior1st"].isnull().sum()
# Out:
# 0

# %%
exterior2nd_mode = df_ov_data["Exterior2nd"].mode()[0]
exterior2nd_mode
# Out:
# 'VinylSd'

# %%
df_cleaned["Exterior2nd"].replace(np.nan, exterior2nd_mode, inplace=True)
df_cleaned["Exterior2nd"].isnull().sum()
# Out:
# 0

# %%
masvnrtype_const = "NA"
df_cleaned["MasVnrType"].replace(np.nan, masvnrtype_const, inplace=True)
df_cleaned["MasVnrType"].isnull().sum()
# Out:
# 0

# %%
masvnrarea_const = df_ov_data["MasVnrArea"].median()
masvnrarea_const
df_cleaned["MasVnrArea"].replace(np.nan, masvnrtype_const, inplace=True)
df_cleaned["MasVnrArea"].isnull().sum()
# Out:
# 0

# %%
bsmtqual_const = "NA"
df_cleaned["BsmtQual"].replace(np.nan, bsmtqual_const, inplace=True)
df_cleaned["BsmtQual"].isnull().sum()
# Out:
# 0

# %%
bsmtcond_const = "NA"
df_cleaned["BsmtCond"].replace(np.nan, bsmtcond_const, inplace=True)
df_cleaned["BsmtCond"].isnull().sum()
# Out:
# 0

# %%
bsmtexposure_const = "NA"
df_cleaned["BsmtExposure"].replace(np.nan, bsmtexposure_const, inplace=True)
df_cleaned["BsmtExposure"].isnull().sum()
# Out:
# 0

# %%
bsmtfintype1_const = "NA"
df_cleaned["BsmtFinType1"].replace(np.nan, bsmtfintype1_const, inplace=True)
df_cleaned["BsmtFinType2"].replace(np.nan, bsmtfintype1_const, inplace=True)
df_cleaned["BsmtFinType1"].isnull().sum()
# Out:
# 0

# %%
bsmtfinsf1_const = "0"
df_cleaned["BsmtFinSF1"].replace(np.nan, bsmtfinsf1_const, inplace=True)
df_cleaned["BsmtFinSF2"].replace(np.nan, bsmtfinsf1_const, inplace=True)
df_cleaned["BsmtFinSF1"].isnull().sum()
# Out:
# 0

# %%
bsmtunfsf_const = "0"
df_cleaned["BsmtUnfSF"].replace(np.nan, bsmtunfsf_const, inplace=True)
df_cleaned["BsmtUnfSF"].isnull().sum()
# Out:
# 0

# %%
totalbsmtsf_const = "0"
df_cleaned["TotalBsmtSF"].replace(np.nan, totalbsmtsf_const, inplace=True)
df_cleaned["TotalBsmtSF"].isnull().sum()
# Out:
# 0

# %%
electrical_mode = df_ov_data["Electrical"].mode()[0]
electrical_mode
df_cleaned["Electrical"].replace(np.nan, electrical_mode, inplace=True)
df_cleaned["Electrical"].isnull().sum()
# Out:
# 0

# %%
df_ov_data["KitchenAbvGr"].value_counts()
# Out:
# KitchenAbvGr
# 1    2785
# 2     129
# 0       3
# 3       2
# Name: count, dtype: int64

# %%
df_ov_data["KitchenQual"].value_counts()
# Out:
# KitchenQual
# TA    1492
# Gd    1151
# Ex     205
# Fa      70
# Name: count, dtype: int64

# %%
bsmtfullbath_mode = df_ov_data["BsmtFullBath"].mode()[0]
bsmtfullbath_mode
df_cleaned["BsmtFullBath"].replace(np.nan, bsmtfullbath_mode, inplace=True)
df_cleaned["BsmtFullBath"].isnull().sum()
# Out:
# 0

# %%
bsmthalfbath_mode = df_ov_data["BsmtHalfBath"].mode()[0]
bsmthalfbath_mode
df_cleaned["BsmtHalfBath"].replace(np.nan, bsmthalfbath_mode, inplace=True)
df_cleaned["BsmtHalfBath"].isnull().sum()
# Out:
# 0

# %%
kitchenqual_count = "Po"
df_cleaned["KitchenQual"].replace(np.nan, kitchenqual_count, inplace=True)
df_cleaned["KitchenQual"].isnull().sum()
# Out:
# 0

# %%
functional_mode = df_ov_data["Functional"].mode()[0]
df_cleaned["Functional"].replace(np.nan, functional_mode, inplace=True)
df_cleaned["Functional"].isnull().sum()
# Out:
# 0

# %%
fireplacequ_count = "NA"
df_cleaned["FireplaceQu"].replace(np.nan, fireplacequ_count, inplace=True)
df_cleaned["FireplaceQu"].isnull().sum()
# Out:
# 0

# %%
poolqc_count = "NA"
df_cleaned["PoolQC"].replace(np.nan, poolqc_count, inplace=True)
df_cleaned["PoolQC"].isnull().sum()
# Out:
# 0

# %%
fence_count = "NA"
df_cleaned["Fence"].replace(np.nan, fence_count, inplace=True)
df_cleaned["Fence"].isnull().sum()
# Out:
# 0

# %%
miscfeature_count = "NA"
df_cleaned["MiscFeature"].replace(np.nan, miscfeature_count, inplace=True)
df_cleaned["MiscFeature"].isnull().sum()
# Out:
# 0

# %%
saletype_mode = df_ov_data["SaleType"].mode()[0]
df_cleaned["SaleType"].replace(np.nan, saletype_mode, inplace=True)
df_cleaned["SaleType"].isnull().sum()
# Out:
# 0

# %% [raw]
# GarageType
# GarageFinish
# GarageCars
# GarageCond

# %% [raw]
# GarageYrBlt
# GarageArea
# GarageQual

# %%
cat_feat = ["GarageType", "GarageFinish", "GarageCars", "GarageCond"]
num_feat = ["GarageYrBlt", "GarageArea", "GarageQual"]

# %%
garage_cat="NA"
for feat in cat_feat:
    df_cleaned[feat].replace(np.nan, garage_cat, inplace=True)

df_cleaned[cat_feat].isnull().sum()
# Out:
# GarageType      0
# GarageFinish    0
# GarageCars      0
# GarageCond      0
# dtype: int64

# %%
garage_num=0
for feat in num_feat:
    df_cleaned[feat].replace(np.nan, garage_num, inplace=True)

df_cleaned[num_feat].isnull().sum()
# Out:
# GarageYrBlt    0
# GarageArea     0
# GarageQual     0
# dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df_cleaned.isnull())
plt.savefig("D:\sonu\project\house_price_pridction\EDA_img\heatmap_df_of_cleaned_features.png")

# %%
plt.figure(figsize=(16,9))
plt.subplot(121)
sns.heatmap(df_ov_data.isnull())
plt.subplot(122)
sns.heatmap(df_cleaned.isnull())
plt.savefig("D:\sonu\project\house_price_pridction\EDA_img\heatmap_df_of_both_features.png")
